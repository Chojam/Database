# %% [markdown]
# <a href="https://colab.research.google.com/github/Chojam/Database/blob/main/Week14_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Open CSV file and print row[1]/title

# %%
# Prints all titles in CSV using csv.reader

import csv

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create reader
    reader = csv.reader(file)

    # Skip header row
    next(reader)

    # Iterate over CSV file, printing each title (row["title"])
    for row in reader:
        print(row[1])
# Out:
# How i met your mother
# The Sopranos
# Friday Night Lights
# Family Guy
# New Girl
# Friends
# Office
# Breaking Bad
# Modern Family
# Office
# White Collar
# Modern Family
# Game of Thrones
# the Untamed
# The 100
# Modern Family
# The Office
# New Girl
# The Office
# Avatar: The Last Airbender
# Cobra Kai
# Sherlock Homes
# New Girl
# arrow
# Grace and Frankie
# The Great British Baking Show
# The Mentalist
# Brooklyn-99
# Avatar The Last Airbender
# Parks and Rec
# Archer
# Friends
# The Simpsons
# Avatar The Last Airbender
# The Flash
# Avatar the Last Airbender
# New Girl
# Stranger Things
# Squid Game
# Friends
# Community
# Curb Your Enthusiasm
# Hannah Montana
# The Simpsons
# The Good Place
# Band of Brothers
# Jeopardy
# The Office
# The Good Place
# Violet Evergarden
# Avatar the Last Airbender
# Game of Thrones
# Breaking Bad
# Criminal Minds
# Shark Tank
# Star Trek: The Next Generation
# Squid Game
# White Collar
# Parks and Recreation
# Mad Men
# Friends
# South Park
# The Office
# Norsemen
# The West Wing
# Regular Show
# Ted Lasso
# The Wire
# Lost
# The Office
# Breaking Bad
# community
# Queen’s Gambit
# Community
# Friends
# How I Met Your Mother
# Six Flying Dragons
# Gilmore Girls
# Reba
# friends
# Evacuate Earth
# Friends
# The Flash
# The Office
# Supernatural
# Peaky Blinders
# Game of Thrones
# Game of Thrones
# Community
# Breaking Bad
# Community
# The Office
# The Good Place
# The Office
# You
# Community
# Grey's Anatomy
# Breaking Bad
# The Crown
# Arrested Development
# Avatar: The Last Airbender
# Black Mirror
# Friends
# Saturday Night Live
# How I Met Your Mother
# The Office
# the bachelorette
# The CROWN
# Law and order
# B99
# GoT
# Sherlock
# WandaVision
# Stranger Things
# The Good Place
# adventure time
# Parks and Rec
# squid game
# Yellowstone
# Brooklyn 99
# criminal minds
# The Haunting of Hill House
# Avatar
# the office
# The Office
# Game Of Thrones
# The Originals
# family guy
# Last Week Tonight with John Oliver
# Community
# WandaVision
# billions
# ThE OffiCE
# Friends
# The Office
# Top Gear
# Six Flying Dragons
# New Amsterdam
# Game of Thrones
# Blue Mountain State
# Community
# Its Always Sunny in Philidelphia
# Thevoffice
# Atlanta
# Good Omens
# The Big Bang Theory
# Grey's anatomy
# Gilmore girls
# Avatar: The Last Airbender
# Avatar the Last Airbender
# Hunter X Hunter
# brooklyn 99
# sherlock holmes
# Anne With An E
# Money Heist
# Succession
# Silicon Valley

# %% [markdown]
# 3. Add and Sort information

# %%
# Prints unique titles in CSV, case sensitively

import csv

# For accumulating (and later sorting) titles
titles = set()

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)

    # Iterate over CSV file, adding each title to set
    for row in reader:
        titles.add(row["title"])

# Print titles in sorted order
for title in sorted(titles):
    print(title)
# Out:
# Anne With An E
# Archer
# Arrested Development
# Atlanta
# Avatar
# Avatar The Last Airbender
# Avatar The Last Airbender
# Avatar the Last Airbender
# Avatar the Last Airbender
# Avatar: The Last Airbender
# B99
# Band of Brothers
# Black Mirror
# Blue Mountain State
# Breaking Bad
# Brooklyn 99
# Brooklyn-99
# Cobra Kai
# Community
# Criminal Minds
# Curb Your Enthusiasm
# Evacuate Earth
# Family Guy
# Friday Night Lights
# Friends
# Friends
# Game Of Thrones
# Game of Thrones
# Gilmore Girls
# Gilmore girls
# GoT
# Good Omens
# Grace and Frankie
# Grey's Anatomy
# Grey's anatomy
# Hannah Montana
# How I Met Your Mother
# How i met your mother
# Hunter X Hunter
# Its Always Sunny in Philidelphia
# Jeopardy
# Last Week Tonight with John Oliver
# Law and order
# Lost
# Mad Men
# Modern Family
# Money Heist
# New Amsterdam
# New Girl
# Norsemen
# Office
# Parks and Rec
# Parks and Recreation
# Peaky Blinders
# Queen’s Gambit
# Reba
# Regular Show
# Saturday Night Live
# Shark Tank
# Sherlock
# Sherlock Homes
# Silicon Valley
# Six Flying Dragons
# South Park
# Squid Game
# Star Trek: The Next Generation
# Stranger Things
# Succession
# Supernatural
# Ted Lasso
# ThE OffiCE
# The 100
# The Big Bang Theory
# The CROWN
# The Crown
# The Flash
# The Good Place
# The Great British Baking Show
# The Haunting of Hill House
# The Mentalist
# The Office
# The Office
# The Originals
# The Simpsons
# The Sopranos
# The West Wing
# The Wire
# Thevoffice
# Top Gear
# Violet Evergarden
# WandaVision
# White Collar
# Yellowstone
# You
# adventure time
# arrow
# billions
# brooklyn 99
# community
# criminal minds
# family guy
# friends
# sherlock holmes
# squid game
# the Untamed
# the bachelorette
# the office

# %% [markdown]
# 4. Change characters to captital letters

# %%
# Prints unique titles in CSV, case insensitively

import csv

# For accumulating (and later sorting) titles
titles = set()

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)

    # Iterate over CSV file, adding each (uppercased) title to set
    for row in reader:
        titles.add(row["title"].strip().upper())

# Print titles in sorted order
for title in sorted(titles):
    print(title)
# Out:
# ADVENTURE TIME
# ANNE WITH AN E
# ARCHER
# ARRESTED DEVELOPMENT
# ARROW
# ATLANTA
# AVATAR
# AVATAR THE LAST AIRBENDER
# AVATAR: THE LAST AIRBENDER
# B99
# BAND OF BROTHERS
# BILLIONS
# BLACK MIRROR
# BLUE MOUNTAIN STATE
# BREAKING BAD
# BROOKLYN 99
# BROOKLYN-99
# COBRA KAI
# COMMUNITY
# CRIMINAL MINDS
# CURB YOUR ENTHUSIASM
# EVACUATE EARTH
# FAMILY GUY
# FRIDAY NIGHT LIGHTS
# FRIENDS
# GAME OF THRONES
# GILMORE GIRLS
# GOOD OMENS
# GOT
# GRACE AND FRANKIE
# GREY'S ANATOMY
# HANNAH MONTANA
# HOW I MET YOUR MOTHER
# HUNTER X HUNTER
# ITS ALWAYS SUNNY IN PHILIDELPHIA
# JEOPARDY
# LAST WEEK TONIGHT WITH JOHN OLIVER
# LAW AND ORDER
# LOST
# MAD MEN
# MODERN FAMILY
# MONEY HEIST
# NEW AMSTERDAM
# NEW GIRL
# NORSEMEN
# OFFICE
# PARKS AND REC
# PARKS AND RECREATION
# PEAKY BLINDERS
# QUEEN’S GAMBIT
# REBA
# REGULAR SHOW
# SATURDAY NIGHT LIVE
# SHARK TANK
# SHERLOCK
# SHERLOCK HOLMES
# SHERLOCK HOMES
# SILICON VALLEY
# SIX FLYING DRAGONS
# SOUTH PARK
# SQUID GAME
# STAR TREK: THE NEXT GENERATION
# STRANGER THINGS
# SUCCESSION
# SUPERNATURAL
# TED LASSO
# THE 100
# THE BACHELORETTE
# THE BIG BANG THEORY
# THE CROWN
# THE FLASH
# THE GOOD PLACE
# THE GREAT BRITISH BAKING SHOW
# THE HAUNTING OF HILL HOUSE
# THE MENTALIST
# THE OFFICE
# THE ORIGINALS
# THE SIMPSONS
# THE SOPRANOS
# THE UNTAMED
# THE WEST WING
# THE WIRE
# THEVOFFICE
# TOP GEAR
# VIOLET EVERGARDEN
# WANDAVISION
# WHITE COLLAR
# YELLOWSTONE
# YOU

# %% [markdown]
# 5. Add how many titles have repeated

# %%
# Prints popularity of titles in CSV, sorted by title

import csv

# For accumulating (and later sorting) titles
titles = {}

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)

    # Iterate over CSV file, adding each (uppercased) title to dictionary
    for row in reader:

        # Canoncalize title
        title = row["title"].strip().upper()

        # Count title
        if title in titles:
            titles[title] += 1
        else:
            titles[title] = 1

# Print titles in sorted order
for title in sorted(titles):
    print(title, titles[title])
# Out:
# ADVENTURE TIME 1
# ANNE WITH AN E 1
# ARCHER 1
# ARRESTED DEVELOPMENT 1
# ARROW 1
# ATLANTA 1
# AVATAR 1
# AVATAR THE LAST AIRBENDER 5
# AVATAR: THE LAST AIRBENDER 3
# B99 1
# BAND OF BROTHERS 1
# BILLIONS 1
# BLACK MIRROR 1
# BLUE MOUNTAIN STATE 1
# BREAKING BAD 5
# BROOKLYN 99 2
# BROOKLYN-99 1
# COBRA KAI 1
# COMMUNITY 8
# CRIMINAL MINDS 2
# CURB YOUR ENTHUSIASM 1
# EVACUATE EARTH 1
# FAMILY GUY 2
# FRIDAY NIGHT LIGHTS 1
# FRIENDS 9
# GAME OF THRONES 6
# GILMORE GIRLS 2
# GOOD OMENS 1
# GOT 1
# GRACE AND FRANKIE 1
# GREY'S ANATOMY 2
# HANNAH MONTANA 1
# HOW I MET YOUR MOTHER 3
# HUNTER X HUNTER 1
# ITS ALWAYS SUNNY IN PHILIDELPHIA 1
# JEOPARDY 1
# LAST WEEK TONIGHT WITH JOHN OLIVER 1
# LAW AND ORDER 1
# LOST 1
# MAD MEN 1
# MODERN FAMILY 3
# MONEY HEIST 1
# NEW AMSTERDAM 1
# NEW GIRL 4
# NORSEMEN 1
# OFFICE 2
# PARKS AND REC 2
# PARKS AND RECREATION 1
# PEAKY BLINDERS 1
# QUEEN’S GAMBIT 1
# REBA 1
# REGULAR SHOW 1
# SATURDAY NIGHT LIVE 1
# SHARK TANK 1
# SHERLOCK 1
# SHERLOCK HOLMES 1
# SHERLOCK HOMES 1
# SILICON VALLEY 1
# SIX FLYING DRAGONS 2
# SOUTH PARK 1
# SQUID GAME 3
# STAR TREK: THE NEXT GENERATION 1
# STRANGER THINGS 2
# SUCCESSION 1
# SUPERNATURAL 1
# TED LASSO 1
# THE 100 1
# THE BACHELORETTE 1
# THE BIG BANG THEORY 1
# THE CROWN 2
# THE FLASH 2
# THE GOOD PLACE 4
# THE GREAT BRITISH BAKING SHOW 1
# THE HAUNTING OF HILL HOUSE 1
# THE MENTALIST 1
# THE OFFICE 13
# THE ORIGINALS 1
# THE SIMPSONS 2
# THE SOPRANOS 1
# THE UNTAMED 1
# THE WEST WING 1
# THE WIRE 1
# THEVOFFICE 1
# TOP GEAR 1
# VIOLET EVERGARDEN 1
# WANDAVISION 2
# WHITE COLLAR 2
# YELLOWSTONE 1
# YOU 1

# %% [markdown]
# 6. Sort by popularity

# %%
# Prints popularity of titles in CSV, sorted by popularity

import csv

# For accumulating (and later sorting) titles
titles = {}

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)

    # Iterate over CSV file, adding each (uppercased) title to dictionary
    for row in reader:

        # Canoncalize title
        title = row["title"].strip().upper()

        # Count title
        if title in titles:
            titles[title] += 1
        else:
            titles[title] = 1

# Function for comparing titles by popularity
def get_value(title):
    return titles[title]

# Print titles in sorted order
for title in sorted(titles, key=get_value, reverse=True):
    print(title, titles[title])
# Out:
# THE OFFICE 13
# FRIENDS 9
# COMMUNITY 8
# GAME OF THRONES 6
# BREAKING BAD 5
# AVATAR THE LAST AIRBENDER 5
# NEW GIRL 4
# THE GOOD PLACE 4
# HOW I MET YOUR MOTHER 3
# MODERN FAMILY 3
# AVATAR: THE LAST AIRBENDER 3
# SQUID GAME 3
# FAMILY GUY 2
# OFFICE 2
# WHITE COLLAR 2
# PARKS AND REC 2
# THE SIMPSONS 2
# THE FLASH 2
# STRANGER THINGS 2
# CRIMINAL MINDS 2
# SIX FLYING DRAGONS 2
# GILMORE GIRLS 2
# GREY'S ANATOMY 2
# THE CROWN 2
# WANDAVISION 2
# BROOKLYN 99 2
# THE SOPRANOS 1
# FRIDAY NIGHT LIGHTS 1
# THE UNTAMED 1
# THE 100 1
# COBRA KAI 1
# SHERLOCK HOMES 1
# ARROW 1
# GRACE AND FRANKIE 1
# THE GREAT BRITISH BAKING SHOW 1
# THE MENTALIST 1
# BROOKLYN-99 1
# ARCHER 1
# CURB YOUR ENTHUSIASM 1
# HANNAH MONTANA 1
# BAND OF BROTHERS 1
# JEOPARDY 1
# VIOLET EVERGARDEN 1
# SHARK TANK 1
# STAR TREK: THE NEXT GENERATION 1
# PARKS AND RECREATION 1
# MAD MEN 1
# SOUTH PARK 1
# NORSEMEN 1
# THE WEST WING 1
# REGULAR SHOW 1
# TED LASSO 1
# THE WIRE 1
# LOST 1
# QUEEN’S GAMBIT 1
# REBA 1
# EVACUATE EARTH 1
# SUPERNATURAL 1
# PEAKY BLINDERS 1
# YOU 1
# ARRESTED DEVELOPMENT 1
# BLACK MIRROR 1
# SATURDAY NIGHT LIVE 1
# THE BACHELORETTE 1
# LAW AND ORDER 1
# B99 1
# GOT 1
# SHERLOCK 1
# ADVENTURE TIME 1
# YELLOWSTONE 1
# THE HAUNTING OF HILL HOUSE 1
# AVATAR 1
# THE ORIGINALS 1
# LAST WEEK TONIGHT WITH JOHN OLIVER 1
# BILLIONS 1
# TOP GEAR 1
# NEW AMSTERDAM 1
# BLUE MOUNTAIN STATE 1
# ITS ALWAYS SUNNY IN PHILIDELPHIA 1
# THEVOFFICE 1
# ATLANTA 1
# GOOD OMENS 1
# THE BIG BANG THEORY 1
# HUNTER X HUNTER 1
# SHERLOCK HOLMES 1
# ANNE WITH AN E 1
# MONEY HEIST 1
# SUCCESSION 1
# SILICON VALLEY 1

# %% [markdown]
# 7. Sort by a lambda function

# %%
# Prints popularity of titles in CSV, sorted by popularity, using a lambda function

import csv

# For accumulating (and later sorting) titles
titles = {}

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)

    # Iterate over CSV file
    for row in reader:

        # Canoncalize title
        title = row["title"].strip().upper()

        # Update counter
        if title in titles:
            titles[title] += 1
        else:
            titles[title] = 1

# Print titles in sorted order
for title in sorted(titles, key=lambda title: titles[title], reverse=True):
    print(title, titles[title])
# Out:
# THE OFFICE 13
# FRIENDS 9
# COMMUNITY 8
# GAME OF THRONES 6
# BREAKING BAD 5
# AVATAR THE LAST AIRBENDER 5
# NEW GIRL 4
# THE GOOD PLACE 4
# HOW I MET YOUR MOTHER 3
# MODERN FAMILY 3
# AVATAR: THE LAST AIRBENDER 3
# SQUID GAME 3
# FAMILY GUY 2
# OFFICE 2
# WHITE COLLAR 2
# PARKS AND REC 2
# THE SIMPSONS 2
# THE FLASH 2
# STRANGER THINGS 2
# CRIMINAL MINDS 2
# SIX FLYING DRAGONS 2
# GILMORE GIRLS 2
# GREY'S ANATOMY 2
# THE CROWN 2
# WANDAVISION 2
# BROOKLYN 99 2
# THE SOPRANOS 1
# FRIDAY NIGHT LIGHTS 1
# THE UNTAMED 1
# THE 100 1
# COBRA KAI 1
# SHERLOCK HOMES 1
# ARROW 1
# GRACE AND FRANKIE 1
# THE GREAT BRITISH BAKING SHOW 1
# THE MENTALIST 1
# BROOKLYN-99 1
# ARCHER 1
# CURB YOUR ENTHUSIASM 1
# HANNAH MONTANA 1
# BAND OF BROTHERS 1
# JEOPARDY 1
# VIOLET EVERGARDEN 1
# SHARK TANK 1
# STAR TREK: THE NEXT GENERATION 1
# PARKS AND RECREATION 1
# MAD MEN 1
# SOUTH PARK 1
# NORSEMEN 1
# THE WEST WING 1
# REGULAR SHOW 1
# TED LASSO 1
# THE WIRE 1
# LOST 1
# QUEEN’S GAMBIT 1
# REBA 1
# EVACUATE EARTH 1
# SUPERNATURAL 1
# PEAKY BLINDERS 1
# YOU 1
# ARRESTED DEVELOPMENT 1
# BLACK MIRROR 1
# SATURDAY NIGHT LIVE 1
# THE BACHELORETTE 1
# LAW AND ORDER 1
# B99 1
# GOT 1
# SHERLOCK 1
# ADVENTURE TIME 1
# YELLOWSTONE 1
# THE HAUNTING OF HILL HOUSE 1
# AVATAR 1
# THE ORIGINALS 1
# LAST WEEK TONIGHT WITH JOHN OLIVER 1
# BILLIONS 1
# TOP GEAR 1
# NEW AMSTERDAM 1
# BLUE MOUNTAIN STATE 1
# ITS ALWAYS SUNNY IN PHILIDELPHIA 1
# THEVOFFICE 1
# ATLANTA 1
# GOOD OMENS 1
# THE BIG BANG THEORY 1
# HUNTER X HUNTER 1
# SHERLOCK HOLMES 1
# ANNE WITH AN E 1
# MONEY HEIST 1
# SUCCESSION 1
# SILICON VALLEY 1

# %% [markdown]
# 8. Count for "The Office"

# %%
import csv
import re

# For counting mentions of The Office
counter = 0

# Open CSV File
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)

    # Iterate over CSV file, counting mentions of OFFICE and THE OFFICE
    for row in reader:
        title = row["title"].strip().upper()
        if re.search("^(OFFICE|THE OFFICE)$", title):
            counter += 1

# Print popularity
print(f"Number of people who like The Office: {counter}")
# Out:
# Number of people who like The Office: 15

# %% [markdown]
# 9. Import CSV file and create 'favorite.db' file
# - create
#
# ![image.png](data:image/png;base64,...)

# %%
# Imports titles and genres from CSV into a SQLite database

import csv

# Create database
from sqlalchemy import create_engine
db = create_engine("sqlite:////content/favorites.db/")
print(db.name)


# Create tables
db.execute("CREATE TABLE shows (id INTEGER, title TEXT NOT NULL, PRIMARY KEY(id))")
db.execute("CREATE TABLE genres (show_id INTEGER, genre TEXT NOT NULL, FOREIGN KEY(show_id) REFERENCES shows(id))")

r_set=db.execute('''select name from sqlite_master where type = 'table' ''')
for row in r_set:
  print(row)

# Open CSV file
with open("favorites.csv", "r") as file:

    # Create DictReader
    reader = csv.DictReader(file)
    show_id = 1
    # Iterate over CSV file
    for row in reader:

        # Canoncalize title
        title = row["title"].strip().upper()

        # Insert title
        db.execute("INSERT INTO shows (id, title) VALUES(?,?)",show_id,title)
        show_id = show_id + 1

        # Insert genres
        for genre in row["genres"].split(", "):
            print(genre + "||"+ str(show_id))
            db.execute("INSERT INTO genres (show_id, genre) VALUES(?, ?)", show_id, genre)
# Out:
# sqlite
# ('shows',)
# ('genres',)
# Comedy||2
# Comedy||3
# Crime||3
# Drama||3
# Horror||3
# Sci-Fi||3
# Talk-Show||3
# Thriller||3
# Drama||4
# Family||4
# Sport||4
# Animation||5
# Comedy||5
# Comedy||6
# Comedy||7
# Comedy||8
# Crime||9
# Drama||9
# Comedy||10
# Comedy||11
# Action||12
# Crime||12
# Drama||12
# Comedy||13
# Family||13
# Action||14
# Adventure||14
# Drama||14
# Fantasy||14
# Thriller||14
# War||14
# Action||15
# Drama||15
# Fantasy||15
# History||15
# Romance||15
# Action||16
# Sci-Fi||16
# Comedy||17
# Family||17
# Comedy||18
# Comedy||19
# Comedy||20
# Adventure||21
# Animation||21
# Action||22
# Sport||22
# Crime||23
# Drama||23
# Mystery||23
# Comedy||24
# Action||25
# Crime||25
# Fantasy||25
# Comedy||26
# Romance||26
# Game-Show||27
# Crime||28
# Mystery||28
# Action||29
# Comedy||29
# Crime||29
# Action||30
# Adventure||30
# Animation||30
# Comedy||30
# Family||30
# Fantasy||30
# Comedy||31
# Action||32
# Animation||32
# Comedy||32
# Comedy||33
# Comedy||34
# Action||35
# Animation||35
# Crime||35
# Action||36
# Crime||36
# Action||37
# Animation||37
# Fantasy||37
# Comedy||38
# Action||39
# Adventure||39
# Action||40
# Adventure||40
# Drama||40
# Thriller||40
# Comedy||41
# Comedy||42
# Comedy||43
# Comedy||44
# Family||44
# Comedy||45
# Comedy||46
# Action||47
# Biography||47
# Documentary||47
# Drama||47
# History||47
# War||47
# Game-Show||48
# Comedy||49
# Comedy||50
# Fantasy||50
# Animation||51
# Drama||51
# Adventure||52
# Comedy||52
# Family||52
# Action||53
# Adventure||53
# Drama||53
# Action||54
# Crime||54
# Drama||54
# Thriller||54
# Crime||55
# Family||56
# Sci-Fi||57
# Action||58
# Horror||58
# Thriller||58
# Crime||59
# Drama||59
# Comedy||60
# Documentary||60
# Drama||61
# Comedy||62
# Comedy||63
# Comedy||64
# Adventure||65
# Comedy||65
# History||65
# Drama||66
# Comedy||67
# Comedy||68
# Crime||69
# Drama||69
# Action||70
# Adventure||70
# Fantasy||70
# Sci-Fi||70
# Comedy||71
# Action||72
# Comedy||73
# Drama||74
# Thriller||74
# Comedy||75
# Comedy||76
# Comedy||77
# Action||78
# Drama||78
# History||78
# Family||79
# Horror||79
# Romance||79
# Comedy||80
# Comedy||81
# Sci-Fi||82
# Comedy||83
# Sci-Fi||84
# Animation||85
# Comedy||85
# Sci-Fi||85
# Action||86
# Drama||86
# Fantasy||86
# Horror||86
# Mystery||86
# Action||87
# Adventure||87
# Crime||87
# Drama||87
# History||87
# Action||88
# Adventure||88
# Comedy||88
# Drama||88
# Family||88
# Fantasy||88
# History||88
# Horror||88
# Musical||88
# Mystery||88
# Romance||88
# Thriller||88
# War||88
# Action||89
# Drama||89
# Family||89
# Fantasy||89
# War||89
# Comedy||90
# Crime||91
# Comedy||92
# Comedy||93
# Drama||93
# Adventure||94
# Comedy||94
# Drama||94
# Comedy||95
# Drama||96
# Thriller||96
# Comedy||97
# Drama||98
# Action||99
# Comedy||99
# Crime||99
# Comedy||100
# Comedy||101
# Action||102
# Adventure||102
# Animation||102
# Fantasy||102
# Action||103
# Adventure||103
# Animation||103
# Biography||103
# Comedy||103
# Crime||103
# Documentary||103
# Drama||103
# Family||103
# Fantasy||103
# Game-Show||103
# History||103
# Horror||103
# Music||103
# Musical||103
# Mystery||103
# News||103
# Reality-TV||103
# Romance||103
# Sci-Fi||103
# Short||103
# Sport||103
# Talk-Show||103
# Thriller||103
# War||103
# Western||103
# Comedy||104
# Comedy||105
# Comedy||106
# Comedy||107
# Reality-TV||108
# Romance||108
# Drama||109
# Crime||110
# Drama||110
# Mystery||110
# Thriller||110
# Comedy||111
# Action||112
# Mystery||113
# Action||114
# Comedy||114
# Drama||114
# Thriller||114
# Action||115
# Adventure||115
# Sci-Fi||115
# Comedy||116
# Family||116
# Fantasy||116
# Adventure||117
# Drama||117
# Romance||117
# Comedy||118
# Action||119
# Drama||119
# Game-Show||119
# Horror||119
# Mystery||119
# Thriller||119
# Western||120
# Comedy||121
# Crime||121
# Crime||122
# Horror||123
# Action||124
# Animation||124
# Fantasy||124
# Comedy||125
# Comedy||126
# Thriller||127
# Drama||128
# Comedy||129
# Comedy||130
# News||130
# Talk-Show||130
# Comedy||131
# Action||132
# Fantasy||132
# Sci-Fi||132
# Comedy||133
# Drama||133
# Comedy||134
# Comedy||135
# Family||135
# Documentary||136
# Action||137
# Adventure||137
# Comedy||137
# Documentary||137
# Family||137
# Action||138
# Drama||138
# History||138
# Drama||139
# Fantasy||140
# Thriller||140
# War||140
# Action||141
# Comedy||141
# Sport||141
# Action||142
# Adventure||142
# Animation||142
# Comedy||142
# Crime||142
# Documentary||142
# Drama||142
# Family||142
# Fantasy||142
# Game-Show||142
# History||142
# Horror||142
# Music||142
# Musical||142
# Mystery||142
# News||142
# Romance||142
# Sci-Fi||142
# Sport||142
# Talk-Show||142
# Thriller||142
# War||142
# Western||142
# Comedy||143
# Drama||143
# Comedy||144
# Drama||145
# Comedy||146
# Drama||146
# Fantasy||146
# Sci-Fi||146
# Comedy||147
# Drama||148
# Comedy||149
# Drama||149
# Action||150
# Animation||150
# Adventure||151
# Comedy||151
# Drama||151
# Family||151
# Fantasy||151
# Action||152
# Adventure||152
# Animation||152
# Comedy||153
# Crime||153
# Crime||154
# Drama||154
# Mystery||154
# Drama||155
# Action||156
# Adventure||156
# Crime||156
# Horror||156
# Mystery||156
# Sci-Fi||156
# Thriller||156
# War||156
# Drama||157
# Comedy||158

# %% [markdown]
# 10, Search respectively

# %%
# Searches CSV for popularity of a title

import csv

# Open database
from sqlalchemy import create_engine
db = create_engine("sqlite:////content/favorites.db/")
print(db.name)

# Prompt user for title
title = input("Title: ").strip()

# Search for title
r_set = db.execute("SELECT COUNT(*) AS counter FROM shows WHERE title LIKE ?", "%" + title + "%")

# Get first (and only) row
# Print popularity
data=r_set.fetchall()
for row in data:
    print(row[0])
# Out:
# sqlite
# Title: The Office
# 13
